# %% [markdown]
# # DATA SET

# %%
import pandas as pd

# %%
    pizza = {'diameter' : [6, 8, 10, 14, 18],
            'harga' : [7, 9, 13, 17.5, 18]}

# %%
df = pd.DataFrame(pizza)

# %%
df.head()
# Out:
#    diameter  harga
# 0         6    7.0
# 1         8    9.0
# 2        10   13.0
# 3        14   17.5
# 4        18   18.0

# %%
import matplotlib.pyplot as plt

df.plot(kind="scatter", x='diameter', y='harga')

plt.title("Perbandingan Diamter Hargga Pizza")
plt.xlabel("Dimater(inch)")
plt.ylabel("Harag (dolar)")
plt.xlim(0, 25)
plt.ylim(0 ,25)
plt.grid(True)
plt.show()

# %%
import numpy as np

# %%
X = np.array(df['diameter'])
y = np.array(df['harga'])

# %%
X
# Out:
# array([ 6,  8, 10, 14, 18])

# %%
y
# Out:
# array([ 7. ,  9. , 13. , 17.5, 18. ])

# %%
X = X.reshape(-1, 1)
X.shape
# Out:
# (5, 1)

# %%
X
# Out:
# array([[ 6],
#        [ 8],
#        [10],
#        [14],
#        [18]])

# %% [markdown]
# # TRAINING MODEL

# %%
from sklearn.linear_model import  LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
X_Feature = np.array([0,25]).reshape(-1, 1)
y_Predict= model.predict(X_Visual)

# %%
plt.scatter(X, y)
plt.plot(X_Feature, y_predik, 'r-')

plt.title("perbandingan diameter dan harga pizza")
plt.xlabel("Diameter (Inch)")
plt.ylabel("Harga (Dollar)")
plt.xlim(0,25)
plt.ylim(0, 25)
plt.grid(True)
plt.show()

# %%
print("titik awal y")
print(f'intercept : {model.intercept_}')
# Out:
# titik awal y
# intercept : 1.965517241379315

# %%
print ("Kemiringan Dari Garis")
print(f'slope : {model.coef_}')
# Out:
# Kemiringan Dari Garis
# slope : [0.9762931]

# %% [markdown]
# # Mencari Nilai Slope

# %% [markdown]
# mencari nilai slope = beta = covariance(X,y) / variance(x)

# %%
print(f'X : \n{X}\n')
# Out:
# X :
# [[ 6]
#  [ 8]
#  [10]
#  [14]
#  [18]]

# %%
print(f"X Bentuk Awal : {X.flatten()}\n")
print(f'y : {y}')
# Out:
# X Bentuk Awal : [ 6  8 10 14 18]
#
# y : [ 7.   9.  13.  17.5 18. ]

# %% [markdown]
# ## Variance

# %%
variance_x = np.var(X.flatten(), ddof=1)
print(f'variance : {variance_x}')
# Out:
# variance : 23.2

# %% [markdown]
# # Covariance

# %%
np.cov(X.flatten(), y)
# Out:
# array([[23.2 , 22.65],
#        [22.65, 24.3 ]])

# %%
covariance_xy = np.cov(X.flatten(), y)[0][1]
print(f'Covariance : {covariance_xy}')
# Out:
# Covariance : 22.650000000000002

# %%
slope = covariance_xy / variance_x
print(f'slpe : {slope}')
# Out:
# slpe : 0.976293103448276

# %% [markdown]
# # Mencari Nilai Intercept

# %%
intercept = np.mean(y) - slope * np.mean(X)

# %%
print(f'intercept : {intercept}')
# Out:
# intercept : 1.9655172413793096

# %% [markdown]
# # PREDIKSI HARGA PIZZA

# %%
diameter_pizza = np.array([12, 20, 23]).reshape(-1,1)
diameter_pizza
# Out:
# array([[12],
#        [20],
#        [23]])

# %%
prediksi_harga = model.predict(diameter_pizza)
prediksi_harga
# Out:
# array([13.68103448, 21.49137931, 24.42025862])

# %% [markdown]
# # EVALUASI

# %% [markdown]
# ## TRAINING DAN TESTING DATASET

# %%
X_train = np.array([6, 8, 10, 14, 18]).reshape(-1 , 1)
y_train = np.array([7, 9, 13 , 17, 18])

# %%
X_test = np.array([8, 9, 11, 16, 12]).reshape(-1, 1)
y_test = np.array([11, 8.5, 15, 18, 11])

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import  r2_score

# %%
y_pred  = model.predict(X_test)
r_squared = r2_score(y_test, y_pred)

# %%
print (f"r2 Square : {r_squared}")
# Out:
# r2 Square : 0.6642676548290933
