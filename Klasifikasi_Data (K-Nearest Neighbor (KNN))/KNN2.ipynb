# %% [markdown]
# # LOADDATA

# %%
import pandas as pd

# %%
data = {
    'Tinggi' : [158, 170, 183, 191, 155, 163, 180, 158, 178],
    'Berat' : [64, 86, 84, 80, 49, 59, 67, 54, 67],
    'Jenis Kelamin' : ['Pria', 'Pria', 'Pria', 'Pria', 'Wanita', 'Wanita','Wanita', 'Wanita', 'Wanita']
}

# %%
df =pd.DataFrame(data)
df
# Out:
#    Tinggi  Berat Jenis Kelamin
# 0     158     64          Pria
# 1     170     86          Pria
# 2     183     84          Pria
# 3     191     80          Pria
# 4     155     49        Wanita
# 5     163     59        Wanita
# 6     180     67        Wanita
# 7     158     54        Wanita
# 8     178     67        Wanita

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
for jk, i in df.groupby("Jenis Kelamin"):
    ax.scatter(i['Tinggi'], i['Berat'], label= jk)

plt.legend(loc='upper right')
plt.title("Sebaran data tinggi badan, berat badan, dan Jenis Kelamin")
plt.xlabel("Tinggi Badan (cm)")
plt.ylabel("Berat Badan (kg)")
plt.grid(True)
plt.show()

# %% [markdown]
# ## Prediksi Jenis kelamin bedasarkan tinggi dan berat badan menggunakan KNN

# %%
import numpy as np

# %%
X_train = np.array(df[['Tinggi', 'Berat']])
y_train = np.array(df['Jenis Kelamin'])


print(f'X_train :{X_train}')
print(f'y_train :{y_train}')
# Out:
# X_train :[[158  64]
#  [170  86]
#  [183  84]
#  [191  80]
#  [155  49]
#  [163  59]
#  [180  67]
#  [158  54]
#  [178  67]]
# y_train :['Pria' 'Pria' 'Pria' 'Pria' 'Wanita' 'Wanita' 'Wanita' 'Wanita' 'Wanita']

# %%
from sklearn.preprocessing import LabelBinarizer

# %%
lb= LabelBinarizer()

# %%
y_train = lb.fit_transform(y_train)

# %%
print(f'y_train : {y_train}')
# Out:
# y_train : [[0]
#  [0]
#  [0]
#  [0]
#  [1]
#  [1]
#  [1]
#  [1]
#  [1]]

# %%
y_train = y_train.flatten()

# %%
print(f'y_train : {y_train}')
# Out:
# y_train : [0 0 0 0 1 1 1 1 1]

# %% [markdown]
# # PREDIKSI KNN

# %%
from sklearn.neighbors import  KNeighborsClassifier

# %%
K = 3 #JUMLAH TETANGGA TERDEKAT
model = KNeighborsClassifier(n_neighbors=K)
model.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %% [markdown]
# # Uji

# %%
tinggi = 155
berat = 70

X_new = np.array([tinggi, berat]).reshape(1, -1)

# %%
X_new
# Out:
# array([[155,  70]])

# %%
y_new = model.predict(X_new)

# %%
y_new
# Out:
# array([1])

# %%
lb.inverse_transform(y_new)
# Out:
# array(['Wanita'], dtype='<U6')
