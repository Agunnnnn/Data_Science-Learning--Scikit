# %%
from sklearn.datasets import make_regression

features, Target= make_regression(n_samples=10, n_features=1, random_state=2)

# %% [markdown]
# ### 🔹 n_samples
#
# Jumlah data (baris)
#
# ### 🔹 n_features
#
# Jumlah fitur / kolom
#
# ### 🔹 random_state
#
# Biar hasil random tetap sama (tidak berubah-ubah)

# %%
features, Target
# Out:
# (array([[-0.05626683],
#         [-0.41675785],
#         [-0.90900761],
#         [-1.05795222],
#         [-2.1361961 ],
#         [-1.79343559],
#         [ 0.50288142],
#         [ 1.64027081],
#         [-1.24528809],
#         [-0.84174737]]),
#  array([  -3.49492301,  -25.88623991,  -56.46153839,  -65.71299166,
#         -132.68636684, -111.39635189,   31.23566621,  101.8827694 ,
#          -77.34905621,  -52.28377675]))

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(feature, targets, 'b.')
plt.show()

# %%
X, y = make_regression(n_samples=10, n_features=1, random_state=10, noise=5.0)

# %% [markdown]
# ### Noise
# Ganguan
# Example
# No Noise <br>
# x = 1 → y = 2 <br>
# x = 2 → y = 4 <br>
# x = 3 → y = 6 <br>
#
# with Noise <br>
# x = 1 → y = 2.3 <br>
# x = 2 → y = 3.7 <br>
# x = 3 → y = 6.5 <br>

# %%
plt.plot(X, y, 'r.')
plt.show()
